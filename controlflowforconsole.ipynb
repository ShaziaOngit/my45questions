# %%
import random
print("High Low Game")

round = 5

def main():
  print("Welcome to the High Low Game")
  print("*****************************")

  your_score = 0
  for i in range(round):
    print("Round",i+1)

    computer_number : int = random.randint(1,100)
    your_number:int = random.randint(1,100)
    print("Your number is", your_number)
    choice:str = input("Do you think your number is higher or lower than the computer's number? ")
    higher_and_correct:bool=choice=="higher"and your_number>computer_number
    lower_and_correct:bool=choice=="lower"and your_number<computer_number

    if higher_and_correct or lower_and_correct:
      print("You were right! The computer\'s number was",computer_number)
      score += 1
    else:
      print("That\'s incorrect.The computer\'s number was",computer_number)

    print("Your score is now",score)
    print()

  print("Thanks for playing!")


if  "_name_" == "_main_":
   main()
# Out:
# High Low Game

# %%
print("Planetary Weight Calculator")

def main():
  print("Welcome to the Planetary Weight Calculator")
  print("******************************************")

earth_weight = float(input("Enter your weight on Earth:"))

gravity_ratios = {
    "Mercury":0.38,
    "Venus" :0.91,
    "Mars" :0.38,
    "Jupiter":2.34,
    "Saturn":1.06,
    "Uranus":0.92,
    "Neptune":1.19

}

print("\n Select a planet")
for planet in gravity_ratios:
  print(f'-{planet}')

planet_choice = input("Enter the name of the planet:").title()

if planet_choice in gravity_ratios:
    new_weight = earth_weight * gravity_ratios [planet_choice]
    print(f'Your weight on{planet_choice} is {new_weight:.2f}kg')
else:
  print("invalid planet choice")

if __name__ =="__main__":
  main()
# Out:
# Planetary Weight Calculator
# Enter your weight on Earth:23
#
#  Select a planet
# -Mercury
# -Venus
# -Mars
# -Jupiter
# -Saturn
# -Uranus
# -Neptune
# Enter the name of the planet:Mars
# Your weight onMars is 8.74kg
# Welcome to the Planetary Weight Calculator
# ******************************************

# %%
print("Lists and Dicts")

my_list =["pen","pencil","rubber","scale","inkpot"]

def access_element(my_list,index):
  """Return the element at the specific index, or an error if out of range."""
  if 0 <= index< len(my_list):
    return f'Element at index {index}{my_list[index]}:'
    return "Index out of range"
def modify_element(my_list,index,new_value):
  """Modifies the element at the specified index with the new value."""
  if 0 <= index < len(my_list):
    my_list[index] = new_value
    return f'Element at index {index} modified to{new_value}'
  return "Index out of range"

  def modify_element(my_list,index,new_value):
    """Modifies the element at the specified index wiyh the new_value."""
    if 0 <= index <len(my_list):
      old_value =my_list[index]
      my_list[index]= new_value
      return f'Element at index {index} modified from {old_value} to {new_value}'
  return "Index out of range"

def slice_list(my_list,start,end):
  """Return a new list containing the elements from the start index to the end index(exclusive)."""
  if 0 <= start <len(my_list) and 0 <=end <= len(my_list):
    return f'Sliced list:{my_list[start:end]}'
  return("Invalid slice indicates!")

def list_game():
  print("\n Welcome to the list manipulation")

  my_list = ["pen","pencil","rubber","scale","inkpot"]
while True:
  print("Current list",my_list)

  print("Select an operation")
  print("1.Access Element")
  print("2.Modify Element")
  print("3.Slice list")
  print("4.Quit")


  choice = input("Enter your choice (1-4)")

  if  choice =="1":
       index =int(input("Enter the index of the element you want to access:"))
       print(access_element(my_list,index))

  elif choice =="2":
      index =int(input("Enter the index of the element you want to modify:"))
      new_value =input("Enter the new value for the element:")
      print(access_element(my_list,index,new_value))
  elif choice =="3":
      start = int(input("Enter the index for the slice:"))
      end =int(input("Enter the end index for the slice:"))
      print(slice_list(my_list,start, end))
  elif choice =="4":
      print("Exiting the game, Thanks for playing.")
      break
  else:
      print("Invalid choice! please enter a number between 1 to 4.")

if   __name__ == "__main__":
   list_game()
# Out:
# Lists and Dicts
# Current list ['pen', 'pencil', 'rubber', 'scale', 'inkpot']
# Select an operation
# 1.Access Element
# 2.Modify Element
# 3.Slice list
# 4.Quit
# Enter your choice (1-4)1
# Enter the index of the element you want to access:2
# Element at index 2rubber:
# Current list ['pen', 'pencil', 'rubber', 'scale', 'inkpot']
# Select an operation
# 1.Access Element
# 2.Modify Element
# 3.Slice list
# 4.Quit
# Enter your choice (1-4)pen
# Invalid choice! please enter a number between 1 to 4.
# Current list ['pen', 'pencil', 'rubber', 'scale', 'inkpot']
# Select an operation
# 1.Access Element
# 2.Modify Element
# 3.Slice list
# 4.Quit
# Enter your choice (1-4)3
# Enter the index for the slice:2
# Enter the end index for the slice:4
# Sliced list:['rubber', 'scale']
# Current list ['pen', 'pencil', 'rubber', 'scale', 'inkpot']
# Select an operation
# 1.Access Element
# 2.Modify Element
# 3.Slice list
# 4.Quit
# Enter your choice (1-4)3
# Enter the index for the slice:3
# Enter the end index for the slice:4
# Sliced list:['scale']
# Current list ['pen', 'pencil', 'rubber', 'scale', 'inkpot']
# Select an operation
# 1.Access Element
# 2.Modify Element
# 3.Slice list
# 4.Quit
# Enter your choice (1-4)3
# Enter the index for the slice:2
# Enter the end index for the slice:1
# Sliced list:[]
# Current list ['pen', 'pencil', 'rubber', 'scale', 'inkpot']
# Select an operation
# 1.Access Element
# 2.Modify Element
# 3.Slice list
# 4.Quit
# Enter your choice (1-4)3
# Enter the index for the slice:0
# Enter the end index for the slice:4
# Sliced list:['pen', 'pencil', 'rubber', 'scale']
# Current list ['pen', 'pencil', 'rubber', 'scale', 'inkpot']
# Select an operation
# 1.Access Element
# 2.Modify Element
# 3.Slice list
# 4.Quit
# Enter your choice (1-4)3
# Enter the index for the slice:2
# Enter the end index for the slice:3
# Sliced list:['rubber']
# Current list ['pen', 'pencil', 'rubber', 'scale', 'inkpot']
# Select an operation
# 1.Access Element
# 2.Modify Element
# 3.Slice list
# 4.Quit
# Enter your choice (1-4)1
# Enter the index of the element you want to access:1
# Element at index 1pencil:
# Current list ['pen', 'pencil', 'rubber', 'scale', 'inkpot']
# Select an operation
# 1.Access Element
# 2.Modify Element
# 3.Slice list
# 4.Quit
# Enter your choice (1-4)4
# Exiting the game, Thanks for playing.
#
#  Welcome to the list manipulation
